# %%
# %load_ext autoreload
# %autoreload 2

# %%
#!conda install -y -c conda-forge osmnx

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import geopandas as gpd
from shapely import affinity, Polygon, Point
import folium
from folium import plugins
from folium.plugins import HeatMap
import osmnx as ox
from math import radians, cos, sin, asin, sqrt
import requests
import urllib
import networkx as nx
import pickle
from scipy import stats

Image.MAX_IMAGE_PIXELS = None

# %% [markdown]
# ## Define Active Area

# %%
#21.542397, -157.997755
#21.503480, -157.911103

#37.218796, -122.040275
#36.981923, -121.777395

# %%
active_zone_bounds =  ((-122.00, -121.75),(37.00, 37.25))

active_zone_bounds
# Out:
# ((-122.0, -121.75), (37.0, 37.25))

# %% [markdown]
# ## Land Use Data
#
# Files:
# * 1_1 = North West (North America)
# * 1_2 = North East (Europe & North Asia

# %%
active_zone_im[0][0], active_zone_im[0][1], active_zone_im[1][0], active_zone_im[1][1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 active_zone_im[0][0], active_zone_im[0][1], active_zone_im[1][0], active_zone_im[1][1]
#
# NameError: name 'active_zone_im' is not defined

# %%
def get_poly_sqr_from_bounds(active_zone_bounds):
    
    active_zone_ll = Polygon([[active_zone_bounds[0][0],active_zone_bounds[1][0]],
                              [active_zone_bounds[0][1],active_zone_bounds[1][0]],
                              [active_zone_bounds[0][1],active_zone_bounds[1][1]],
                              [active_zone_bounds[0][0],active_zone_bounds[1][1]],
                              [active_zone_bounds[0][0],active_zone_bounds[1][0]]])

    return active_zone_ll

def get_active_area_zones_form_bounds(active_zone_bounds):
    active_zone_im = np.array(((21600-active_zone_bounds[1][1]*240, 21600-active_zone_bounds[1][0]*240),
                           (active_zone_bounds[0][0]*240, active_zone_bounds[0][1]*240)))#np.array(active_zone_bounds)*240

    active_zone_im = active_zone_im.astype(int)

    return active_zone_im

def get_land_use_from_pixel_bbox(active_zone_bounds):
    # Get_converted_zones
    active_zone_im = get_active_area_zones_form_bounds(active_zone_bounds)
    
    # Open Land Use File
    im = np.array(Image.open('../data/gm_lc_v3/gm_lc_v3_1_2.tif'))
    print('Image size: {}, lat scale factor: {}, lng scale factor: {}'.format(im.shape,im.shape[0]/90, im.shape[1]/180))
    
    im = im[active_zone_im[0][0]: active_zone_im[0][1], active_zone_im[1][0]: active_zone_im[1][1]]
    
    # Open Ukraine Border Filem
    #shapefile = gpd.read_file("../data/ukraine_border/nv937bq8361.shp").iloc[0].geoms[-1]   # The last polygon has the largest area. This is used as 'Ukraine'
    
    return im, im.shape, active_zone_im

# %%
# Get and Plot Land Use Data
ukraine_land_use, im_shape, active_zone_im = get_land_use_from_pixel_bbox(active_zone_bounds)

plt.imshow(ukraine_land_use)
# Out:
# Image size: (21600, 43200), lat scale factor: 240.0, lng scale factor: 240.0

# %%
def get_heatmap_from_array_for_folium(ukraine_land_use, land_use_code):
    heatmap = []
    intensities = []
    
    for x in range(len(ukraine_land_use)):
        for y in range(len(ukraine_land_use[0])):
            intensities.append(float(ukraine_land_use[x][y]))
            if ukraine_land_use[x][y] == land_use_code:   # 5 = Trees
                heatmap.append([active_zone_ll.bounds[3] - (x/240) , (y)/240 + active_zone_ll.bounds[0], float(ukraine_land_use[x][y])/13])

    print('Unique landuse codes: {}, selected: {}'.format(np.unique(intensities), land_use_code))

    return heatmap

# %%
active_zone_ll = get_poly_sqr_from_bounds(active_zone_bounds)

lon, lat = active_zone_ll.centroid.coords[0]
zoom_start_val = 9

# Basemap
m = folium.Map([lat, lon], tiles='OpenStreetMap', zoom_start=zoom_start_val)#, tiles='OpenStreetMap')

# Bounding box around active zone = Red
active_zone_ll = get_poly_sqr_from_bounds(active_zone_bounds)
sim_geo = gpd.GeoSeries(active_zone_ll).simplify(tolerance=0.001)
geo_j = sim_geo.to_json()
geo_j = folium.GeoJson(data=geo_j, style_function=lambda x: {"fill":False,"color": "red"})#orange"})
geo_j.add_to(m)

# Heatmap of selected land use code
heatmap = get_heatmap_from_array_for_folium(ukraine_land_use, 5)

HeatMap(heatmap,#gradient={0.1: 'blue', 0.3: 'lime', 0.5: 'yellow', 0.7: 'orange', 1: 'red'}, 
        use_local_extrema=False,
        radius=7#,zmin=1.0,zmax=15.0
       ).add_to(folium.FeatureGroup(name='Heat Map').add_to(m))
folium.LayerControl().add_to(m)

m
# Out:
# Unique landuse codes: [ 6.  8. 10. 11. 12. 13. 16. 18.], selected: 5
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a0c3d1c5caff658f0be7503f2dee167 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a0c3d1c5caff658f0be7503f2dee167&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a0c3d1c5caff658f0be7503f2dee167 = L.map(
#                 &quot;map_1a0c3d1c5caff658f0be7503f2dee167&quot;,
#                 {
#                     center: [37.125, -121.875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a4dd1534122894c6a7cdc0d74eac79c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1a0c3d1c5caff658f0be7503f2dee167);
#
#
#         function geo_json_950766977c98c15cfb1e86eaed413a46_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fill&quot;: false};
#             }
#         }
#
#         function geo_json_950766977c98c15cfb1e86eaed413a46_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_950766977c98c15cfb1e86eaed413a46 = L.geoJson(null, {
#                 onEachFeature: geo_json_950766977c98c15cfb1e86eaed413a46_onEachFeature,
#
#                 style: geo_json_950766977c98c15cfb1e86eaed413a46_styler,
#         });
#
#         function geo_json_950766977c98c15cfb1e86eaed413a46_add (data) {
#             geo_json_950766977c98c15cfb1e86eaed413a46
#                 .addData(data)
#                 .addTo(map_1a0c3d1c5caff658f0be7503f2dee167);
#         }
#             geo_json_950766977c98c15cfb1e86eaed413a46_add({&quot;bbox&quot;: [-122.0, 37.0, -121.75, 37.25], &quot;features&quot;: [{&quot;bbox&quot;: [-122.0, 37.0, -121.75, 37.25], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.0, 37.0], [-121.75, 37.0], [-121.75, 37.25], [-122.0, 37.25], [-122.0, 37.0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             var feature_group_5897cf4040c4b927f298df2ad76b4be0 = L.featureGroup(
#                 {}
#             ).addTo(map_1a0c3d1c5caff658f0be7503f2dee167);
#
#
#             var heat_map_e485edb3002383e3cea2184b080790be = L.heatLayer(
#                 [],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 7, &quot;useLocalExtrema&quot;: false}
#             ).addTo(feature_group_5897cf4040c4b927f298df2ad76b4be0);
#
#
#             var layer_control_9afb47ac8b861124ec64bd3d79730b75 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_7a4dd1534122894c6a7cdc0d74eac79c,
#                 },
#                 overlays :  {
#                     &quot;macro_element_950766977c98c15cfb1e86eaed413a46&quot; : geo_json_950766977c98c15cfb1e86eaed413a46,
#                     &quot;Heat Map&quot; : feature_group_5897cf4040c4b927f298df2ad76b4be0,
#                 },
#             };
#             L.control.layers(
#                 layer_control_9afb47ac8b861124ec64bd3d79730b75.base_layers,
#                 layer_control_9afb47ac8b861124ec64bd3d79730b75.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_1a0c3d1c5caff658f0be7503f2dee167);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plt.imshow(ukraine_land_use == 5)

# %% [markdown]
# ## Open Street Maps Land Use Data

# %%
def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance in kilometers between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 3956 #6371 # Radius of earth in kilometers. Use 3956 for miles. Determines return value units.
    return c * r

# %%
(haversine(active_zone_bounds[0][0], active_zone_bounds[1][0], active_zone_bounds[0][1], active_zone_bounds[1][0]), 
 haversine(active_zone_bounds[0][0], active_zone_bounds[1][0], active_zone_bounds[0][0], active_zone_bounds[1][1]))
# Out:
# (13.785488202054845, 17.261306302223723)

# %%
xy_factor = haversine(active_zone_bounds[0][0], active_zone_bounds[1][0], active_zone_bounds[0][0], active_zone_bounds[1][1])/haversine(active_zone_bounds[0][0], active_zone_bounds[1][0], active_zone_bounds[0][1], active_zone_bounds[1][0])

int(xy_factor*50)
# Out:
# 62

# %%
x_points, xy_factor
# Out:
# (101, 1.2521360179069159)

# %%
geometry_type = 'grid' # grid or polygons

tags = {'landuse': ['forest'], 'natural': ['wood']} #

active_zone_ll = get_poly_sqr_from_bounds(active_zone_bounds)

geometries = ox.geometries_from_bbox(active_zone_bounds[1][0], active_zone_bounds[1][1], 
                                     active_zone_bounds[0][0], active_zone_bounds[0][1], tags=tags)

geometries.reset_index(inplace = True)

if geometry_type == 'grid':
    
    div_factor = 0.9
    active_zone_bounds =  ((-122.00, -121.75),(37.00, 37.25))
    points = []
    x_points = int(100*(active_zone_bounds[0][1] - active_zone_bounds[0][0])/div_factor) 
    xy_factor = haversine(active_zone_bounds[0][0], active_zone_bounds[1][0], active_zone_bounds[0][0], active_zone_bounds[1][1])/haversine(active_zone_bounds[0][0], active_zone_bounds[1][0], active_zone_bounds[0][1], active_zone_bounds[1][0]) 

    for x in range(x_points + 1):
        for y in range(int(x_points*xy_factor) + 1):
            point = Point(active_zone_bounds[0][0] + x/x_points*(active_zone_bounds[0][1] - active_zone_bounds[0][0]),
                          active_zone_bounds[1][0] + y/int(x_points*xy_factor)*(active_zone_bounds[0][1] - active_zone_bounds[0][0]))

            if np.sum(geometries.apply(lambda row:row['geometry'].intersects(point), axis=1)) > 0:
                points.append(point)

    geometries = pd.DataFrame(points, columns=['geometry'])

len(geometries), geometries.head(2), geometries.tail(2)
# Out:
# /tmp/ipykernel_124366/628469368.py:7: UserWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in a future release.
#   geometries = ox.geometries_from_bbox(active_zone_bounds[1][0], active_zone_bounds[1][1],
# (484,
#                            geometry
#  0                  POINT (-122 37)
#  1  POINT (-122 37.015151515151516),
#                                 geometry
#  482   POINT (-121.75 37.10606060606061)
#  483  POINT (-121.75 37.121212121212125))

# %%
active_zone_ll = get_poly_sqr_from_bounds(active_zone_bounds)
lon, lat = active_zone_ll.centroid.coords[0]
zoom_start_val = 11
min_area = 1e-6
polygons = []
centroids = []

# Basemap
m = folium.Map([lat, lon], tiles='OpenStreetMap', zoom_start=zoom_start_val)#, height=500)#, tiles='OpenStreetMap')

# Bounding box around active zone = Red
sim_geo = gpd.GeoSeries(active_zone_ll).simplify(tolerance=0.001)
geo_j = sim_geo.to_json()
geo_j = folium.GeoJson(data=geo_j, style_function=lambda x: {"fill":False,"color": "red"})#orange"})
geo_j.add_to(m)

# Plot OSM Results
for tree_geom in geometries['geometry']:
    #if tree_geom.area > min_area:
    # Plot Polygon
    # sim_geo = gpd.GeoSeries(tree_geom)#.simplify(tolerance=0.001)
    # geo_j = sim_geo.to_json()
    # geo_j = folium.GeoJson(data=geo_j, style_function=lambda x: {"color": "green", "width": 2})#orange"})
    # geo_j.add_to(m)
    # polygons.append(tree_geom)

    # Plot Centroids
    if tree_geom.geom_type == 'Polygon':
        centroid = tree_geom.centroid
    elif tree_geom.geom_type == 'Point':
        centroid = tree_geom

    folium.Circle(location=[centroid.y, centroid.x],
                            radius=0.4,
                            color = 'green').add_to(m)#weight=5, color = 'green').add_to(m)

    centroids.append(centroid)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35b5a63b9e05f8e703f2fdda70a17273 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35b5a63b9e05f8e703f2fdda70a17273&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35b5a63b9e05f8e703f2fdda70a17273 = L.map(
#                 &quot;map_35b5a63b9e05f8e703f2fdda70a17273&quot;,
#                 {
#                     center: [37.125, -121.875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_02f3dbe8c497b5f0a67bab17e2cfe957 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_35b5a63b9e05f8e703f2fdda70a17273);
#
#
#         function geo_json_454fda0962bf322ca021748f0ba1d5ab_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fill&quot;: false};
#             }
#         }
#
#         function geo_json_454fda0962bf322ca021748f0ba1d5ab_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_454fda0962bf322ca021748f0ba1d5ab = L.geoJson(null, {
#                 onEachFeature: geo_json_454fda0962bf322ca021748f0ba1d5ab_onEachFeature,
#
#                 style: geo_json_454fda0962bf322ca021748f0ba1d5ab_styler,
#         });
#
#         function geo_json_454fda0962bf322ca021748f0ba1d5ab_add (data) {
#             geo_json_454fda0962bf322ca021748f0ba1d5ab
#                 .addData(data)
#                 .addTo(map_35b5a63b9e05f8e703f2fdda70a17273);
#         }
#             geo_json_454fda0962bf322ca021748f0ba1d5ab_add({&quot;bbox&quot;: [-122.0, 37.0, -121.75, 37.25], &quot;features&quot;: [{&quot;bbox&quot;: [-122.0, 37.0, -121.75, 37.25], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.0, 37.0], [-121.75, 37.0], [-121.75, 37.25], [-122.0, 37.25], [-122.0, 37.0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             var circle_beca9d0ad068ad6c54dc242838867119 = L.circle(
#                 [37.0, -122.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_35b5a63b9e05f8e703f2fdda70a17273);
#
#
#             var circle_cdb630915f231fdcd4548b9054362ae0 = L.circle(
#                 [37.00694444444444, -122.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_35b5a63b9e05f8e703f2fdda70a17273);
#
#
#             var circle_f82e88d03573736f7d61931c2cdab67d = L.circle(
#                 [37.020833333333336, -122.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_35b5a63b9e05f8e703f2fdda70a17273);
#
#
#             var circle_fc83162211550f5845628eca38568385 = L.circle(
#                 [37.02777777777778, -122.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_35b5a63b9e05f8e703f2fdda70a17273);
#
#
#             var circle_4ee1ca525a27eeca811cc0230b2bf42

# %%
# USGS Elevation Point Query Service
url = r'https://epqs.nationalmap.gov/v1/json?'

# coordinates with known elevation 
lat = [centroid.y for centroid in centroids]
lon = [centroid.x for centroid in centroids]

# create data frame
elevation_df = pd.DataFrame({
    'lat': lat,
    'lon': lon
})

def elevation_function(df, lat_column, lon_column):
    """Query service using lat, lon. add the elevation values as a new column."""
    elevations = []
    for lat, lon in zip(df[lat_column], df[lon_column]):
                
        # define rest query params
        params = {
            'output': 'json',
            'x': lon,
            'y': lat,
            'units': 'Meters'}
        
        # format query string and return query value
        result = requests.get((url + urllib.parse.urlencode(params)))
        #elevations.append(result.json()['USGS_Elevation_Point_Query_Service']['Elevation_Query']['Elevation'])
        #new 2023:
        elevations.append(result.json()['value'])

    elevation_df['elev_meters'] = elevations

elevation_function(elevation_df, 'lat', 'lon')
elevation_df.head()

#### KS TODO: Convert Meter to Feet!!!
# Out:
#          lat    lon    elev_meters
# 0  37.000000 -122.0   69.071693420
# 1  37.006944 -122.0   77.722152710
# 2  37.020833 -122.0   90.559463501
# 3  37.027778 -122.0  141.274139404
# 4  37.034722 -122.0  173.148300171

# %%
#elevation_df.to_csv('../data/elevations_grid.csv')
elevation_df = pd.read_csv('../data/elevations_grid.csv')

# %%
elev_to_max_dist = {40: {25: 1.73, 50: 1.42, 100: 1.11, 200: 0.79},# wind speed: {effective tree height: max distance}
                    30: {25: 1.29, 50: 1.07, 100: 0.83, 200: 0.60},
                    20: {25: 0.87, 50: 0.72, 100: 0.57, 200: 0.42},
                    10: {25: 0.44, 50: 0.36, 100: 0.29, 200: 0.20}}

def max_spotting_distance(wind_speed, difference_in_elevation):
    slope, intercept, r_value, p_value, std_err = stats.linregress(list(elev_to_max_dist[wind_speed].keys()),
                                                                   list(elev_to_max_dist[wind_speed].values()))

    difference_in_elevation = 3.28084*difference_in_elevation # convert from meters to feet
    
    return slope*(difference_in_elevation) + intercept # returns results in miles

# %%
elevation_df['elev_meters'] = elevation_df.elev_meters.astype(float)

# %%
G = nx.Graph()
#cutoff_distance = 1.0 # miles
wind_speed = 20

centroids = []

for tree_num1, tree_geom in enumerate(geometries['geometry']):
    if tree_num1 % 100 == 0:
        print(tree_num1)
        
    if type(geometries['geometry'][tree_num1]) == Point:
        lon1 = geometries['geometry'][tree_num1].coords.xy[0][0]
        lat1 = geometries['geometry'][tree_num1].coords.xy[1][0]
        centroids.append(geometries['geometry'][tree_num1])
    else:
        lon1 = geometries['geometry'][tree_num1].centroid.coords.xy[0][0]
        lat1 = geometries['geometry'][tree_num1].centroid.coords.xy[1][0]
        centroids.append(geometries['geometry'][tree_num1].centroid)
    
    G.add_node(tree_num1, pos=(lon1, lat1))
    
    for tree_num2 in range(0,tree_num1):
        if type(geometries['geometry'][tree_num2]) == Point:
            lon2 = geometries['geometry'][tree_num2].coords.xy[0][0]
            lat2 = geometries['geometry'][tree_num2].coords.xy[1][0]
        else:
            lon2 = geometries['geometry'][tree_num2].centroid.coords.xy[0][0]
            lat2 = geometries['geometry'][tree_num2].centroid.coords.xy[1][0]

        ## Cutoff for Edge
        distance = haversine(lon1, lat1, lon2, lat2)

        difference_in_elevation = elevation_df.loc[tree_num1, 'elev_meters'] - elevation_df.loc[tree_num2, 'elev_meters']
        cutoff_distance = max_spotting_distance(wind_speed, difference_in_elevation)

        ## Could change to edge of polygons instead of centroids -> higher connectivity
        if distance < cutoff_distance:
            #print('included, distance: {}, cutoff: {}'.format(distance, cutoff_distance))
            G.add_edge(tree_num1, tree_num2)
# Out:
# 0
# 100
# 200
# 300
# 400

# %%
len(list(G.nodes)), len(list(G.edges))
# Out:
# (484, 5961)

# %%
lon, lat = active_zone_ll.centroid.coords[0]
zoom_start_val = 9

# Basemap
m = folium.Map([lat, lon], tiles='OpenStreetMap', zoom_start=zoom_start_val)#, tiles='OpenStreetMap')

# Bounding box around active zone = Red
active_zone_ll = get_poly_sqr_from_bounds(active_zone_bounds)
sim_geo = gpd.GeoSeries(active_zone_ll).simplify(tolerance=0.001)
geo_j = sim_geo.to_json()
geo_j = folium.GeoJson(data=geo_j, style_function=lambda x: {"fill":False,"color": "red"})#orange"})
geo_j.add_to(m)

# Plot OSM Results
for tree_geom in geometries['geometry']:

    if tree_geom.area > min_area:
        if tree_geom.geom_type == 'Polygon':
            centroid = tree_geom.centroid
        elif tree_geom.geom_type == 'Point':
            centroid = tree_geom

        folium.CircleMarker(location=[centroid.y, centroid.x],
                            radius=0.1,
                            color = 'green').add_to(m)  #weight=5, color = 'green').add_to(m)

# Plot edges
for edge in G.edges():
    c1 = centroids[edge[0]]
    c2 = centroids[edge[1]]
    folium.PolyLine([[c1.y,c1.x],[c2.y,c2.x]], weight=1).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d8710cad89d3bd827ca51029d9dcae4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d8710cad89d3bd827ca51029d9dcae4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d8710cad89d3bd827ca51029d9dcae4 = L.map(
#                 &quot;map_9d8710cad89d3bd827ca51029d9dcae4&quot;,
#                 {
#                     center: [37.125, -121.875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3bafddb2814c7c2ad0d9be8323ab902a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9d8710cad89d3bd827ca51029d9dcae4);
#
#
#         function geo_json_1239b79f0a2f19ad3a3f172e196b4cee_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fill&quot;: false};
#             }
#         }
#
#         function geo_json_1239b79f0a2f19ad3a3f172e196b4cee_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1239b79f0a2f19ad3a3f172e196b4cee = L.geoJson(null, {
#                 onEachFeature: geo_json_1239b79f0a2f19ad3a3f172e196b4cee_onEachFeature,
#
#                 style: geo_json_1239b79f0a2f19ad3a3f172e196b4cee_styler,
#         });
#
#         function geo_json_1239b79f0a2f19ad3a3f172e196b4cee_add (data) {
#             geo_json_1239b79f0a2f19ad3a3f172e196b4cee
#                 .addData(data)
#                 .addTo(map_9d8710cad89d3bd827ca51029d9dcae4);
#         }
#             geo_json_1239b79f0a2f19ad3a3f172e196b4cee_add({&quot;bbox&quot;: [-122.0, 37.0, -121.75, 37.25], &quot;features&quot;: [{&quot;bbox&quot;: [-122.0, 37.0, -121.75, 37.25], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.0, 37.0], [-121.75, 37.0], [-121.75, 37.25], [-122.0, 37.25], [-122.0, 37.0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             var poly_line_01813789e1fdb03bca6cdd600f98f646 = L.polyline(
#                 [[37.015151515151516, -122.0], [37.02272727272727, -122.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_9d8710cad89d3bd827ca51029d9dcae4);
#
#
#             var poly_line_f8af190310bebfa2fcf7db8433f67a1b = L.polyline(
#                 [[37.03030303030303, -122.0], [37.03787878787879, -122.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_9d8710cad89d3bd827ca51029d9dcae4);
#
#
#             var poly_line_0256622273d9c0f4dc193411e8c11a84 = L.polyline(
#                 [[37.03787878787879, -122.0], [37.04545454545455, -122.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_9d8710cad89d3bd827ca51029d9dcae4);
#
#
#             var poly_line_8f392068a71d8f7c97d2d0185ea141ae = L.polyline(
#                 [[37.04545454545455, -122.0], [37.053030303030305, -122.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quo

# %%
pickle.dump(G, open('../data/fire_graph.pkl', 'wb'))
# Out:
# /tmp/ipykernel_124366/23483827.py:1: ResourceWarning: unclosed file <_io.BufferedWriter name='../data/fire_graph.pkl'>
#   pickle.dump(G, open('../data/fire_graph.pkl', 'wb'))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
# Tree Cover Height = 100 

# elev_to_max_dist = {400: {10: 0.12, 20: 0.26, 30: 0.39, 40: 0.51},# effective tree height: {wind speed: max distance}
#                     600: {10: 0.20, 20: 0.49, 30: 0.59, 40: 0.78},
#                     800: {10: 0.27, 20: 0.54, 30: 0.77, 40: 1.04}}


elev_to_max_dist = {40: {25: 1.73, 50: 1.42, 100: 1.11, 200: 0.79},# wind speed: {effective tree height: max distance}
                    30: {25: 1.29, 50: 1.07, 100: 0.83, 200: 0.60},
                    20: {25: 0.87, 50: 0.72, 100: 0.57, 200: 0.42},
                    10: {25: 0.44, 50: 0.36, 100: 0.29, 200: 0.20}}

# %%
slope_40, intercept_40, r_value, p_value, std_err = stats.linregress(list(elev_to_max_dist[40].keys()),
                                                               list(elev_to_max_dist[40].values()))

slope_30, intercept_30, r_value, p_value, std_err = stats.linregress(list(elev_to_max_dist[30].keys()),
                                                               list(elev_to_max_dist[30].values()))

slope_20, intercept_20, r_value, p_value, std_err = stats.linregress(list(elev_to_max_dist[20].keys()),
                                                               list(elev_to_max_dist[20].values()))


slope_10, intercept_10, r_value, p_value, std_err = stats.linregress(list(elev_to_max_dist[10].keys()),
                                                               list(elev_to_max_dist[10].values()))


print('40 equation: {}*x + {}'.format(slope_40, intercept_40))
print('30 equation: {}*x + {}'.format(slope_30, intercept_30))
print('20 equation: {}*x + {}'.format(slope_20, intercept_20))
print('10 equation: {}*x + {}'.format(slope_10, intercept_10))
# Out:
# 40 equation: -0.005019130434782608*x + 1.7330434782608695
# 30 equation: -0.0037043478260869564*x + 1.2947826086956522
# 20 equation: -0.0024*x + 0.8699999999999999
# 10 equation: -0.0012765217391304347*x + 0.44217391304347825

# %%
wind_speed = 20
